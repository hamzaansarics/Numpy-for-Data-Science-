# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.style as st
st.use('ggplot')
smesters=[1,2,3,4,5]
cgpa=[3.81,3.50,3.55,3.4,3.5]
plt.plot(smesters,cgpa)
plt.xlabel('Smesters')
plt.ylabel('CGPA')
plt.grid(color='k')
plt.show()
