# %%
import cv2
import time
import random
import datetime as dt
import matplotlib.pyplot as plt
from matplotlib import style
import matplotlib.animation as animation
import numpy as np
from numpy.fft import fft,fftfreq,ifft
#--------------------------------------------------------------#
#------------------------------OpenCV--------------------------#
#--------------------------------------------------------------#
# cam=cv2.VideoCapture(0)
# img=cv2.imread('D:\\7.1.08.tiff',0)
# img=cv2.imread('D:\\Ansari.jpg',0)
# rimg=cv2.resize(img,(480, 640))
# path='D:\\khan.jpg'
# cv2.imwrite(path,img)
# img=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
# hist=cv2.calcHist([img],[0],None,[256],[0,256])
# point1=np.float32(([0,0],[100,200],[300,100],[200,300]))
# point2=np.float32(([0,0],[200,100],[100,200],[300,200]))
# def emp(x):
#         pass
# windowName='Bl'
# cv2.namedWindow(windowName)
# cv2.createTrackbar('Bl',windowName,0,10,emp)
# for e in dir(cv2):
#         if e.startswith('EVENT'):
#             print(e)
# def motion(eve,x,y,flags,params):
#         if eve==cv2.EVENT_LBUTTONDOWN:
#             cv2.circle(img,(x,y),10,(255,0,0),-1)
#         if eve==cv2.EVENT_MOUSEMOVE:
#             cv2.line(img,(x,y),(x,y),(0,25,0),2)
# cv2.setMouseCallback(windowName,motion)
# count=0
# ker=np.ones(img.shape,np.uint8)
# cv2.line(ker,(100,200),(300,400),(0,255,0),10)
# cv2.circle(ker,(300,200),20,(255,0,0),-1)
# cv2.rectangle(ker,(100,200),(300,400),(0,255,0),10)
# cv2.ellipse(ker,(200,200),(80,160),0,0,360,(0,255,0),-1)
# cv2.putText(ker,'Hamza Ansari',(200,200),cv2.FONT_HERSHEY_SIMPLEX,1,(0,255,0))
# plt.imshow(ker)
# rows,colums,channels=rimg.shape
# prob=0.7
# for r in range(rows):
#     for c in range(colums):
#         rnd=random.random()
#         if rnd<prob/2:
#             ker[r][c]=[0,255,0]
#         elif rnd<prob:
#             ker[r][c]=[0,0,0]
#         else:
#             ker[r][c]=rimg[r][c]
# oi=cv2.medianBlur(ker,13)
# plt.subplot(1,2,1)
# plt.title('Noised')
# plt.imshow(ker)
# plt.subplot(1,2,2)
# plt.title('Denoised')
# plt.imshow(oi)
# resulotion=(640,480)
# fr=10
# path='D:\\VideoSaver\\Khan_Saye1.mp4'
# codec=cv2.VideoWriter_fourcc('X','V','I','D')
# vr=cv2.VideoWriter(path,codec,fr,resulotion)
# mask=cv2.imread('D:\\MASK.jpg')
# dimg=cv2.imread('D:\\damedgimg.jpg')
# low=np.array([0,0,0])
# high=np.array([50,50,50])
# mask=cv2.inRange(dimg,low,high)
# cv2.imwrite('D:\\MASK.jpg',mask)
# out=cv2.inpaint(dimg,mask,7,cv2.INPAINT_NS)
# color_img=cv2.cvtColor(out,cv2.COLOR_BGR2RGB)
# plt.imshow(color_img)
# windowName='Trackbar'
# cv2.namedWindow(windowName)
# def emp(x):
#     pass
# cv2.createTrackbar('R',windowName,0,255,emp)
# cv2.createTrackbar('G',windowName,0,255,emp)
# cv2.createTrackbar('B',windowName,0,255,emp)
# while True:
#     ret,frame=cam.read()
#     count+=1
#     hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
#     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     rgb=cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
#     for c in dir(cv2):
#         if c.startswith('COLOR'):
#             print(c)
#     rows,colums,channels=frame.shape
#     wa=cv2.getAffineTransform(point1,point2)
#     ou=cv2.warpAffine(frame,wa,(rows,colums))
#     R,G,B=cv2.split(frame)
#     R_A=cv2.equalizeHist(R)
#     G_A=cv2.equalizeHist(G)
#     B_A=cv2.equalizeHist(B)
#     clahi=cv2.createCLAHE(clipLimit=True,tileGridSize=(8,8))
#     clahi=cv2.createCLAHE()
#     R_C=clahi.apply(R)
#     G_C=clahi.apply(G)
#     B_C=clahi.apply(B)
#     R_A=cv2.equalizeHist(R_C)
#     G_A=cv2.equalizeHist(G_C)
#     B_A=cv2.equalizeHist(B_C)
#     output=cv2.merge((R_A,G_A,B_A))
#     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     ath=cv2.adaptiveThreshold(gray,140,cv2.ADAPTIVE_THRESH_MEAN_C,cv2.THRESH_BINARY,773,2)
#     cv2.imshow('Adjusted Equalize',output)
#     m1=frame+frame
#     m2=frame-frame
#     m3=frame/frame
#     m4=frame%frame
#     m5=frame*frame
#     alpha=cv2.getTrackbarPos('Bl',windowName)/10
#     beta=1-alpha
#     print(alpha)
#     bl=cv2.addWeighted(frame,alpha,frame,beta,0)
#     low=np.array([36,75,119])
#     high=np.array([151,280,235])
#     hsv=cv2.cvtColor(frame,cv2.COLOR_BGR2HSV)
#     img_mask=cv2.inRange(frame,low,high)
#     ext=cv2.bitwise_and(frame,frame,mask=img_mask)
#     gray=cv2.cvtColor(frame,cv2.COLOR_BGR2GRAY)
#     ret,th=cv2.threshold(gray,100,255,0)
#     im,cont,hir=cv2.findContours(th,cv2.RETR_TREE,cv2.CHAIN_APPROX_NONE)
#     con=cv2.drawContours(frame,cont,-1,(0,255,0),2)
#     edge=cv2.Canny(frame,200,150)
#     ker=np.float32([[-1,-1,-1],[-1,8,-1],[-1,-1,-1]])
#     own_detector=cv2.filter2D(frame,-1,ker) 
#     lap=cv2.Laplacian(frame,-1)
#     sobelx=cv2.Sobel(frame,-1,1,0)
#     sobely=cv2.Sobel(frame,-1,0,1)
#     schar=cv2.Scharr(frame,-1,0,1)
#     print(frame.size*frame.itemsize)
#     ba=cv2.bitwise_not(frame)
#     bl=cv2.boxFilter(frame,-1,(11,11))
#     b=cv2.blur(frame,(5,5))
#     gb=cv2.GaussianBlur(frame,(11,11),-1)
#     mb=cv2.medianBlur(rimg,19)
#     cv2.imshow('Orignal',rimg)
#     R,G,B=cv2.split(frame)
#     M=np.maximum(np.maximum(R,G),B)
#     R[R<M]=0
#     G[G<M]=0
#     B[B<M]=0
#     output=cv2.merge((R,G,B))
#     ret,bth=cv2.threshold(frame,120,255,0)
#     erosion=cv2.erode(bth,ker,iterations=3)
#     dilotion=cv2.dilate(bth,ker,iterations=3)
#     mg=cv2.morphologyEx(frame,cv2.MORPH_GRADIENT,ker)   
#     rows,colums,chann=frame.shape
#     P=cv2.getPerspectiveTransform(point1,point2)
#     WP=cv2.warpPerspective(frame,P,(rows,colums))
#     vr.write(frame)
#     print(cam.get(3))
#     print(cam.get(4))
#     cam.set(3,352)
#     cam.set(4,288)
#     print(cam.get(3))
#     print(cam.get(4))   
#     R=cv2.getRotationMatrix2D((rows,colums),50,1)
#     WR=cv2.warpAffine(frame,R,(rows,colums))
#     S=np.float32(([1,0,-50],[0,1,400]))
#     WS=cv2.warpAffine(frame,S,(rows,colums))
#     ret,binr=cv2.threshold(gray,0,255,cv2.THRESH_BINARY+cv2.THRESH_OTSU)
#     ret,bin_inv=cv2.threshold(gray,0,255,cv2.THRESH_BINARY_INV+cv2.THRESH_OTSU)
#     ret,tozero=cv2.threshold(gray,0,255,cv2.THRESH_TOZERO+cv2.THRESH_OTSU)
#     ret,tozero_inv=cv2.threshold(gray,0,255,cv2.THRESH_TOZERO_INV+cv2.THRESH_OTSU)
#     ret,trunc=cv2.threshold(gray,0,0,cv2.THRESH_TRUNC+cv2.THRESH_OTSU)
#     R=cv2.getTrackbarPos('R',windowName)
#     G=cv2.getTrackbarPos('G',windowName)
#     B=cv2.getTrackbarPos('B',windowName)
#     frame[:]=[R,G,B]+frame[:]
#     cv2.imshow(windowName,frame) 
#     if cv2.waitKey(1)==27:
#         break
# print(count)
# cv2.destroyAllWindows()
# vr.release()
# cam.release()
#--------------------------------------------------------------#
#----------------------------Matplotlib------------------------#
#--------------------------------------------------------------#
# style.use('fivethirtyeight')
# fig=plt.figure()
# ax=plt.subplot2grid((1,1),(0,0))
# ax=fig.add_subplot(1,1,1)
# years=[2002,2002,2004,2006,2008,2010,2012,2014,2016,2018,2020]
# prices=[500,200,50,900,500,600,1000,900,150,100,300]
# bins=[b*50 for b in range(24)]
# days=[1,2,3,4,5,6,7]
# work=[20,202,204,206,200,201,202,201,201,201,202]
# enjoy=[50,20,5,90,50,60,100,90,15,10,30]
# eat=[3,2,4,1,3,5,6]
# sleep=[10,9,12,7,6,5,8]
# slices=[5,7,4,8,2]
# act=['days','work','enjoy','eat','sleep']
# colors=['g','r','y','c','b']
# ax.plot([],[],label='Profit',color='g')
# ax.plot([],[],label='Loss',color='r')
# for label in ax.yaxis.get_ticklabels():
#     label.set_visible(False)
# for label in ax.xaxis.get_ticklabels():
#     label.set_rotation(45)
# plt.xlabel('Years',color='g')
# plt.ylabel('Prices',color='g')
# ax.text(2007.8,600,'Profit',color='g',alpha=0.5)
# ax.axhline(400,linewidth=1,color='w',alpha=0.5)
# box_style=dict(boxstyle='round4',ec='k',fc='w')
# yr=np.array(years)
# pr=np.array(prices)
# ax.fill_between(years,prices,400,where=(pr>400),facecolor='g',alpha=0.5)
# ax.fill_between(years,prices,400,where=(pr<400),facecolor='r',alpha=0.5)
# ax.annotate(str(200),(years[0],prices[0]),(years[10]+1.5,prices[1]),alpha=0.5)#bbox=box_style)
# ax.annotate(str(400),(years[0],prices[0]),(years[10]+1.5,400),alpha=0.5)#,bbox=box_style)
# ax.annotate(str(600),(years[0],prices[0]),(years[10]+1.5,600),alpha=0.5)#,bbox=box_style)
# ax.annotate(str(800),(years[0],prices[0]),(years[10]+1.5,800),alpha=0.5)#,bbox=box_style)
# ax.annotate(str(1000),(years[0],prices[0]),(years[10]+1.5,1000),alpha=0.5)#,bbox=box_style)
# ax.spines['left'].set_visible(False)
# ax.spines['top'].set_visible(False)
# ax.grid(True,color='w')
# plt.xlim(xmax=2020,xmin=2002)
# plt.ylim(ymax=1000,ymin=50)
# ax.bar(yr,pr,width=1.5,color='c',alpha=0.7,label='Bar')
# ax.stackplot(yr,pr,color='c',alpha=0.5)
# ax.hist(prices,bins,histtype='bar',rwidth=0.5)
# ax.pie(slices,labels=act,colors=colors,autopct='%1.2f%%',shadow=True)
# ax.set_xticks([2002,2002,2004,2006,2008,2010,2012,2014,2016,2018,2020])
# ax.set_yticks([500,200,50,900,500,600,1000,900,150,100,300])
# lg=ax.legend(loc=2,ncol=1,prop={'size':8})
# lg.get_frame().set_visible(True)
# lg.get_frame().set_color('w')
# plt.show()
# t1=time.time()
# t=dt.datetime.fromtimestamp
# print(t(t1))
# def ani(i):
#     data=open('C:\\Users\\Hamza\\Desktop\\Data_Set.txt').read()
#     xs,ys=[],[]
#     for lines in data.split('\n'):
#             xs.append(lines[0])
#             ys.append(lines[2])
#     print(xs)
#     ax.clear()
#     ax.plot(xs,ys)
# ani=animation.FuncAnimation(fig,ani,interval=100)
# ani
# plt.title('Matplotlib')
# ax1.scatter(years,prices,color='g',linewidth=1,alpha=0.5,label='Scatter',s=500,marker='*')
# plt.setp(ax.get_yticklabels(),visible=True,color='g',rotation=45,alpha=1,size=20)
# ax2=plt.subplot2grid((6,1),(1,0),rowspan=4,colspan=1,sharey=ax1,sharex=ax1)
# ax2.scatter(years,prices,color='g',linewidth=1,alpha=0.5,label='Scatter',s=500,marker='*')
# ax3=plt.subplot2grid((6,1),(5,0),rowspan=1,colspan=1,sharex=ax2,sharey=ax2)
# ax3.scatter(years,prices,color='g',linewidth=1,alpha=0.5,label='Scatter',s=500,marker='*')
# print(plt.style.available)
# print(plt.__file__)
# plt.plot(years,prices)
# axv=ax.twinx()
# a=[x*50 for x in range(100)]
# b=[s*90 for s in range(100)]
# axv.fill_between(a,b)
#--------------------------------------------------------------#
#-----------------------------Numpy----------------------------#
#--------------------------------------------------------------#
# arr=np.indices((5,5))
mine1=np.array([[5,1,4]])
mine2=np.array([[1,2,4],[5,1,4],[5,1,4],[1,2,4]])
# am=np.array([b,[4,5,6]])
# print(arr)
# print(arr.dtype)
# print(arr.ndim)
# print(arr.size)
# print(arr.size*arr.itemsize)
# ar=np.ones((5,5))
# ar1=np.zeros((5,5))
# max1=np.max(arr)
# min1=np.min(arr)
# print(arr.max(ax'is=1))
# print(arr.max(axis=0))
# ls=np.linspace(1,100,90)
# arng=np.arange(1,2,0.001)
# ind=np.indices((3,3),np.float32)
# plt.imshow(np.cos(ind),cmap='gray' )
# print(np.cos(ind))
# print(np.sin(ind))
# print(np.tan(ind))
# rnd_int=np.random.randint(1,255,500)
# rnd_float=np.random.uniform(1,255.10,100)
# print(arr.sum())
# print(arr.sum(axis=1))
# print(arr.sum(axis=0))
# print(np.multiply(arr,arr))
# print(np.add(arr,arr))
# print(np.dot(mine1,mine2))
# dt=np.dot(arr,arr)
# print(np.inner(arr,arr))
# print(np.outer(arr,arr))
# print(arr.flatten())
# print(np.std(mine1))
# print(mine1.sum(axis=1)/3)
# print(mine1.mean())
# print(mine1.var())
# print(mine1.argmax())
# print(mine1.argmin())
# print(mine1.argsort())
# print(np.sort(mine1))
# print(mine1.cumsum())
# print(mine1.cumsum(axis=0))
# print(mine1.cumsum(axis=1))
# print(mine1.cumprod())
# print(mine1.cumprod(axis=1))
# print(mine1.cumprod(axis=0))
# print(np.median(mine1))
# print(np.average(mine1,weights=mine1))=print(np.sum(mine1*mine1)/mine1.sum())
# print(arr.nonzero())
# d1=np.uint8([3,10,2,10])
# d2=np.uint16([[3,10,2,10],[3,10,2,10]])
# d3=np.uint32([3,10,2,10])
# d4=np.uint64([3,10,2,10])
# a1=np.float16([[3,10,2,10],[3,10,2,10]])
# a2=np.float32([[3,10,2,10],[3,10,2,10]])
# a3=np.float64([[3,10,2,10],[3,10,2,10]])
# c1=np.int8([3,10,2,10])
# c2=np.int16([[3,10,2,10],[3,10,2,10]])
# c3=np.int32([3,10,2,10])
# c4=np.int64([3,10,2,10])
# print(np.diff(mine1))
# emp=np.empty((2,2),dtype=np.float64)
# idt=np.identity(5)
# e=np.eye(5,10)
# f_q=fftfreq(20)
# fft=fft(mine1)
# m_g=np.mgrid[0:256:20,0:256:90]
# o_g=np.ogrid[-11:11:2,-11:11:2]
# x=np.linspace(-5,5,20)
# y=np.linspace(-7,7,20)
# xx1,yy1=np.meshgrid(x,y,indexing='ij')
# xx2,yy2=np.meshgrid(img,mine2)
# inv=np.linalg.inv(img)
# print(np.sqrt(mine1))
# print(np.exp(mine1))
# nm=np.power(mine1,2)
# eigl,eiglc=np.linalg.eig(img)
# plt.imshow(np.real(eiglc))
# xg,yg=np.broadcast_arrays(mine1,mine2)
# mine2=mine2.flatten()
# hist,cool=np.histogram(img,30)
# plt.plot(hist)
