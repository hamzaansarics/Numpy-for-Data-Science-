# %%
import numpy as np
import matplotlib.pyplot as plt
np.random.seed(4500)
height=np.random.randint(1,1000,50)
print(height)
print(bins)
bins=[b*20 for b in range(60)]
hist,cool=np.histogram(height,50)
plt.plot(hist)
# Out:
# [615 690 498 209 859 360 604 631 515 454 783 890 606 638 824 257 676 569
#  381 129 862 244 898 377  67 565 531 910 791 792 211 428 658 743 971 299
#  200 320 979 756 588  29 121 681 491 438 796 748 543 982]
# [0, 20, 40, 60, 80, 100, 120, 140, 160, 180, 200, 220, 240, 260, 280, 300, 320, 340, 360, 380, 400, 420, 440, 460, 480, 500, 520, 540, 560, 580, 600, 620, 640, 660, 680, 700, 720, 740, 760, 780, 800, 820, 840, 860, 880, 900, 920, 940, 960, 980, 1000, 1020, 1040, 1060, 1080, 1100, 1120, 1140, 1160, 1180]
