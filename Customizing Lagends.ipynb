# %%
import matplotlib.pyplot as plt
from matplotlib import style
style.use('bmh')
fig=plt.figure()
ax=plt.figure(facecolor='r')
x=[24,6,8,10]
y=[1,2,3,4]
plt.plot(x,y,label='Hamza',linewidth=0.5)
leg=ax.legend(loc=10,ncol=2,prop={'size':10})
leg.get_frame().set_alpha(0)
plt.show()
